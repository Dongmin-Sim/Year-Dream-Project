# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# To ignore deprecated warnings
import os
import warnings
warnings.simplefilter("ignore")
warnings.warn("deprecated", DeprecationWarning)
import os
import random
import numpy as np
from gensim.models import word2vec #  word2vec 관련 모델을 제공해주는 library  
import nltk
from nltk.corpus import movie_reviews # corpus 를 가져오는 용도 
from sklearn.manifold import TSNE # 시각화를 위한 TSNE 사용 
from sklearn.metrics import accuracy_score # accuracy score 를 계산하기 위한 metric 라이브러리 불러오기 
import matplotlib as mpl
import matplotlib.pyplot as plt
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

from torch.utils import data # pytorch data class 
import torch.nn as nn # pytorch neural network 불러오기 
import torch.nn.utils.rnn as rnn_utils # rnn utils
import torch

import pickle

# os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# # Chapter 1

# %% [markdown]
# # Word embedding (CBOW & Skip-Gram)

# %% [markdown]
# ![대체 텍스트](./figures/embedding.png)

# %% [markdown]
# ![대체 텍스트](./figures/w2vec_1.png)

# %%
# 파라메터값 지정
num_features = 300 # 임베딩 벡터 사이즈
negative = 10 # negative sampling할 단어 수
min_word_count = 10 # 한 문장에 대한 최소 문자 수"
window = 5 # context window 사이즈
downsampling = 0.75 # 단어의 빈도수가 높은 단어에 대해 빈도수를 낮춤
epoch = 5 # epoch 수

# %%
# preparing data
data_path = '/content/drive/MyDrive/Colab Notebooks/yeardream/24._20220120_DAY23/drive-download-20220120T000210Z-001/실습1'
sentences = []
pos_data = open(os.path.join(data_path, "lm_data/pos/train.txt")).readlines()
neg_data = open(os.path.join(data_path, "lm_data/neg/train.txt")).readlines()
data_ = pos_data + neg_data
for line in data_:
    sentences.append(line.strip().split(' '))

print(len(sentences))
# Out:
# 62966

# %%
# skip-gram 모델 학습
skip_gram = word2vec.Word2Vec(sentences,
                              sg = 1, # skip-gram
                              negative=negative,
                              size=num_features, 
                              min_count=min_word_count,
                              window=window,
                              sample=downsampling,
                              iter=epoch)

# CBOW 모델 학습
CBOW = word2vec.Word2Vec(sentences,
                              sg = 0, # CBOW
                              negative=negative,
                              size=num_features, 
                              min_count=min_word_count,
                              window=window,
                              sample=downsampling,
                              iter=epoch)
# Out:
# 2022-01-20 06:44:36,782 : INFO : collecting all words and their counts
# 2022-01-20 06:44:36,788 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 06:44:36,837 : INFO : PROGRESS: at sentence #10000, processed 239982 words, keeping 20149 word types
# 2022-01-20 06:44:36,885 : INFO : PROGRESS: at sentence #20000, processed 475267 words, keeping 28557 word types
# 2022-01-20 06:44:36,935 : INFO : PROGRESS: at sentence #30000, processed 718530 words, keeping 35153 word types
# 2022-01-20 06:44:36,982 : INFO : PROGRESS: at sentence #40000, processed 942659 words, keeping 40650 word types
# 2022-01-20 06:44:37,029 : INFO : PROGRESS: at sentence #50000, processed 1164181 words, keeping 45109 word types
# 2022-01-20 06:44:37,076 : INFO : PROGRESS: at sentence #60000, processed 1387734 words, keeping 49141 word types
# 2022-01-20 06:44:37,090 : INFO : collected 50290 word types from a corpus of 1453943 raw words and 62966 sentences
# 2022-01-20 06:44:37,092 : INFO : Loading a fresh vocabulary
# 2022-01-20 06:44:37,129 : INFO : effective_min_count=10 retains 9220 unique words (18% of original 50290, drops 41070)
# 2022-01-20 06:44:37,130 : INFO : effective_min_count=10 leaves 1358527 word corpus (93% of original 1453943, drops 95416)
# 2022-01-20 06:44:37,159 : INFO : deleting the raw counts dictionary of 50290 items
# 2022-01-20 06:44:37,161 : INFO : sample=0.75 downsamples 0 most-common words
# 2022-01-20 06:44:37,164 : INFO : downsampling leaves estimated 1358527 word corpus (100.0% of prior 1358527)
# 2022-01-20 06:44:37,184 : INFO : estimated required memory for 9220 words and 300 dimensions: 26738000 bytes
# 2022-01-20 06:44:37,191 : INFO : resetting layer weights
# 2022-01-20 06:44:38,952 : INFO : training model with 3 workers on 9220 vocabulary and 300 features, using sg=1 hs=0 sample=0.75 negative=10 window=5
# 2022-01-20 06:44:39,997 : INFO : EPOCH 1 - PROGRESS: at 5.39% examples, 71878 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:41,131 : INFO : EPOCH 1 - PROGRESS: at 11.92% examples, 77092 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:42,137 : INFO : EPOCH 1 - PROGRESS: at 18.00% examples, 79099 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:43,186 : INFO : EPOCH 1 - PROGRESS: at 25.00% examples, 81660 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:44,227 : INFO : EPOCH 1 - PROGRESS: at 30.69% examples, 81438 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:45,332 : INFO : EPOCH 1 - PROGRESS: at 37.22% examples, 81955 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:46,387 : INFO : EPOCH 1 - PROGRESS: at 43.81% examples, 82832 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:47,387 : INFO : EPOCH 1 - PROGRESS: at 50.25% examples, 84064 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:48,432 : INFO : EPOCH 1 - PROGRESS: at 56.03% examples, 82672 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:49,505 : INFO : EPOCH 1 - PROGRESS: at 63.99% examples, 84009 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:50,649 : INFO : EPOCH 1 - PROGRESS: at 71.20% examples, 83824 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:51,676 : INFO : EPOCH 1 - PROGRESS: at 79.00% examples, 85106 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:52,888 : INFO : EPOCH 1 - PROGRESS: at 86.21% examples, 84397 words/s, in_qsize 5, out_qsize 1
# 2022-01-20 06:44:53,928 : INFO : EPOCH 1 - PROGRESS: at 92.42% examples, 84155 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:54,831 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:44:54,919 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:44:54,930 : INFO : EPOCH 1 - PROGRESS: at 100.00% examples, 85069 words/s, in_qsize 0, out_qsize 1
# 2022-01-20 06:44:54,931 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:44:54,932 : INFO : EPOCH - 1 : training on 1453943 raw words (1358527 effective words) took 16.0s, 85058 effective words/s
# 2022-01-20 06:44:56,082 : INFO : EPOCH 2 - PROGRESS: at 5.49% examples, 65275 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:57,166 : INFO : EPOCH 2 - PROGRESS: at 11.96% examples, 75169 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:58,415 : INFO : EPOCH 2 - PROGRESS: at 19.42% examples, 77717 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:44:59,446 : INFO : EPOCH 2 - PROGRESS: at 26.27% examples, 80783 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:00,471 : INFO : EPOCH 2 - PROGRESS: at 32.07% examples, 80928 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:01,629 : INFO : EPOCH 2 - PROGRESS: at 39.23% examples, 82244 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:02,724 : INFO : EPOCH 2 - PROGRESS: at 45.79% examples, 82634 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:03,759 : INFO : EPOCH 2 - PROGRESS: at 52.33% examples, 83483 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:04,761 : INFO : EPOCH 2 - PROGRESS: at 58.85% examples, 83540 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:05,880 : INFO : EPOCH 2 - PROGRESS: at 66.14% examples, 83554 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:07,067 : INFO : EPOCH 2 - PROGRESS: at 74.01% examples, 83861 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:08,074 : INFO : EPOCH 2 - PROGRESS: at 81.85% examples, 85232 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 06:45:09,231 : INFO : EPOCH 2 - PROGRESS: at 89.06% examples, 84876 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:10,405 : INFO : EPOCH 2 - PROGRESS: at 96.72% examples, 85072 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:10,716 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:45:10,767 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:45:10,784 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:45:10,785 : INFO : EPOCH - 2 : training on 1453943 raw words (1358527 effective words) took 15.8s, 85743 effective words/s
# 2022-01-20 06:45:11,904 : INFO : EPOCH 3 - PROGRESS: at 6.16% examples, 75527 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:12,937 : INFO : EPOCH 3 - PROGRESS: at 11.92% examples, 78064 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:13,994 : INFO : EPOCH 3 - PROGRESS: at 18.67% examples, 81415 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:15,050 : INFO : EPOCH 3 - PROGRESS: at 25.70% examples, 83281 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:16,089 : INFO : EPOCH 3 - PROGRESS: at 30.76% examples, 80976 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:17,092 : INFO : EPOCH 3 - PROGRESS: at 37.22% examples, 82898 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:18,291 : INFO : EPOCH 3 - PROGRESS: at 43.81% examples, 82049 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:19,410 : INFO : EPOCH 3 - PROGRESS: at 50.31% examples, 82203 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:20,469 : INFO : EPOCH 3 - PROGRESS: at 56.66% examples, 81882 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:21,634 : INFO : EPOCH 3 - PROGRESS: at 64.69% examples, 82579 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:22,677 : INFO : EPOCH 3 - PROGRESS: at 71.17% examples, 82444 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:23,827 : INFO : EPOCH 3 - PROGRESS: at 78.27% examples, 82310 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:24,886 : INFO : EPOCH 3 - PROGRESS: at 85.47% examples, 82748 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:25,972 : INFO : EPOCH 3 - PROGRESS: at 91.79% examples, 82365 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:27,037 : INFO : EPOCH 3 - PROGRESS: at 98.89% examples, 82715 words/s, in_qsize 2, out_qsize 0
# 2022-01-20 06:45:27,038 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:45:27,108 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:45:27,120 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:45:27,121 : INFO : EPOCH - 3 : training on 1453943 raw words (1358527 effective words) took 16.3s, 83204 effective words/s
# 2022-01-20 06:45:28,150 : INFO : EPOCH 4 - PROGRESS: at 4.74% examples, 63880 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:29,228 : INFO : EPOCH 4 - PROGRESS: at 11.28% examples, 75307 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:30,323 : INFO : EPOCH 4 - PROGRESS: at 17.29% examples, 75774 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:31,373 : INFO : EPOCH 4 - PROGRESS: at 23.66% examples, 76881 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:32,379 : INFO : EPOCH 4 - PROGRESS: at 30.07% examples, 79929 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 06:45:33,411 : INFO : EPOCH 4 - PROGRESS: at 35.84% examples, 80137 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:34,472 : INFO : EPOCH 4 - PROGRESS: at 41.89% examples, 79976 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:35,477 : INFO : EPOCH 4 - PROGRESS: at 47.68% examples, 80402 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:36,552 : INFO : EPOCH 4 - PROGRESS: at 53.87% examples, 80099 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:37,581 : INFO : EPOCH 4 - PROGRESS: at 60.36% examples, 80275 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:38,601 : INFO : EPOCH 4 - PROGRESS: at 67.59% examples, 81312 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:39,623 : INFO : EPOCH 4 - PROGRESS: at 74.06% examples, 81390 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:40,626 : INFO : EPOCH 4 - PROGRESS: at 79.70% examples, 80872 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:41,677 : INFO : EPOCH 4 - PROGRESS: at 86.88% examples, 81449 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:42,837 : INFO : EPOCH 4 - PROGRESS: at 93.92% examples, 81378 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:43,581 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:45:43,597 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:45:43,673 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:45:43,674 : INFO : EPOCH - 4 : training on 1453943 raw words (1358527 effective words) took 16.5s, 82109 effective words/s
# 2022-01-20 06:45:44,684 : INFO : EPOCH 5 - PROGRESS: at 4.63% examples, 65214 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:45,742 : INFO : EPOCH 5 - PROGRESS: at 10.62% examples, 72308 words/s, in_qsize 6, out_qsize 0
# 2022-01-20 06:45:46,747 : INFO : EPOCH 5 - PROGRESS: at 17.29% examples, 78966 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:48,004 : INFO : EPOCH 5 - PROGRESS: at 24.36% examples, 77699 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:49,095 : INFO : EPOCH 5 - PROGRESS: at 30.76% examples, 79242 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:50,225 : INFO : EPOCH 5 - PROGRESS: at 37.22% examples, 79819 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:51,232 : INFO : EPOCH 5 - PROGRESS: at 43.81% examples, 81490 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:52,420 : INFO : EPOCH 5 - PROGRESS: at 50.31% examples, 81071 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:53,435 : INFO : EPOCH 5 - PROGRESS: at 56.66% examples, 81266 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:54,449 : INFO : EPOCH 5 - PROGRESS: at 63.99% examples, 82283 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:55,452 : INFO : EPOCH 5 - PROGRESS: at 70.49% examples, 82460 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:56,542 : INFO : EPOCH 5 - PROGRESS: at 76.95% examples, 81981 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:57,714 : INFO : EPOCH 5 - PROGRESS: at 84.79% examples, 82446 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:58,737 : INFO : EPOCH 5 - PROGRESS: at 91.08% examples, 82422 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:45:59,825 : INFO : EPOCH 5 - PROGRESS: at 98.89% examples, 83234 words/s, in_qsize 2, out_qsize 1
# 2022-01-20 06:45:59,831 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:45:59,878 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:45:59,904 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:45:59,905 : INFO : EPOCH - 5 : training on 1453943 raw words (1358527 effective words) took 16.2s, 83747 effective words/s
# 2022-01-20 06:45:59,906 : INFO : training on a 7269715 raw words (6792635 effective words) took 81.0s, 83909 effective words/s
# 2022-01-20 06:45:59,907 : INFO : collecting all words and their counts
# 2022-01-20 06:45:59,908 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-01-20 06:45:59,957 : INFO : PROGRESS: at sentence #10000, processed 239982 words, keeping 20149 word types
# 2022-01-20 06:46:00,004 : INFO : PROGRESS: at sentence #20000, processed 475267 words, keeping 28557 word types
# 2022-01-20 06:46:00,052 : INFO : PROGRESS: at sentence #30000, processed 718530 words, keeping 35153 word types
# 2022-01-20 06:46:00,096 : INFO : PROGRESS: at sentence #40000, processed 942659 words, keeping 40650 word types
# 2022-01-20 06:46:00,140 : INFO : PROGRESS: at sentence #50000, processed 1164181 words, keeping 45109 word types
# 2022-01-20 06:46:00,183 : INFO : PROGRESS: at sentence #60000, processed 1387734 words, keeping 49141 word types
# 2022-01-20 06:46:00,195 : INFO : collected 50290 word types from a corpus of 1453943 raw words and 62966 sentences
# 2022-01-20 06:46:00,198 : INFO : Loading a fresh vocabulary
# 2022-01-20 06:46:00,233 : INFO : effective_min_count=10 retains 9220 unique words (18% of original 50290, drops 41070)
# 2022-01-20 06:46:00,233 : INFO : effective_min_count=10 leaves 1358527 word corpus (93% of original 1453943, drops 95416)
# 2022-01-20 06:46:00,256 : INFO : deleting the raw counts dictionary of 50290 items
# 2022-01-20 06:46:00,259 : INFO : sample=0.75 downsamples 0 most-common words
# 2022-01-20 06:46:00,264 : INFO : downsampling leaves estimated 1358527 word corpus (100.0% of prior 1358527)
# 2022-01-20 06:46:00,283 : INFO : estimated required memory for 9220 words and 300 dimensions: 26738000 bytes
# 2022-01-20 06:46:00,286 : INFO : resetting layer weights
# 2022-01-20 06:46:01,980 : INFO : training model with 3 workers on 9220 vocabulary and 300 features, using sg=0 hs=0 sample=0.75 negative=10 window=5
# 2022-01-20 06:46:03,013 : INFO : EPOCH 1 - PROGRESS: at 25.70% examples, 346188 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:04,013 : INFO : EPOCH 1 - PROGRESS: at 50.95% examples, 354481 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:05,042 : INFO : EPOCH 1 - PROGRESS: at 79.70% examples, 357534 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:05,716 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:46:05,723 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:46:05,725 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:46:05,727 : INFO : EPOCH - 1 : training on 1453943 raw words (1358527 effective words) took 3.7s, 363408 effective words/s
# 2022-01-20 06:46:06,772 : INFO : EPOCH 2 - PROGRESS: at 25.70% examples, 344038 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:07,779 : INFO : EPOCH 2 - PROGRESS: at 50.31% examples, 347664 words/s, in_qsize 6, out_qsize 1
# 2022-01-20 06:46:08,822 : INFO : EPOCH 2 - PROGRESS: at 79.72% examples, 354350 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:09,486 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:46:09,499 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:46:09,502 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:46:09,504 : INFO : EPOCH - 2 : training on 1453943 raw words (1358527 effective words) took 3.8s, 361112 effective words/s
# 2022-01-20 06:46:10,543 : INFO : EPOCH 3 - PROGRESS: at 25.70% examples, 343446 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:11,549 : INFO : EPOCH 3 - PROGRESS: at 51.60% examples, 356673 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:12,588 : INFO : EPOCH 3 - PROGRESS: at 81.09% examples, 360736 words/s, in_qsize 4, out_qsize 1
# 2022-01-20 06:46:13,198 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:46:13,224 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:46:13,233 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:46:13,234 : INFO : EPOCH - 3 : training on 1453943 raw words (1358527 effective words) took 3.7s, 364865 effective words/s
# 2022-01-20 06:46:14,254 : INFO : EPOCH 4 - PROGRESS: at 25.57% examples, 350413 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:15,266 : INFO : EPOCH 4 - PROGRESS: at 51.67% examples, 359212 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:16,267 : INFO : EPOCH 4 - PROGRESS: at 79.70% examples, 360872 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:16,920 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:46:16,949 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:46:16,953 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:46:16,954 : INFO : EPOCH - 4 : training on 1453943 raw words (1358527 effective words) took 3.7s, 365949 effective words/s
# 2022-01-20 06:46:17,963 : INFO : EPOCH 5 - PROGRESS: at 25.70% examples, 354531 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:18,970 : INFO : EPOCH 5 - PROGRESS: at 51.60% examples, 362122 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:20,005 : INFO : EPOCH 5 - PROGRESS: at 80.37% examples, 361816 words/s, in_qsize 5, out_qsize 0
# 2022-01-20 06:46:20,649 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-01-20 06:46:20,661 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-01-20 06:46:20,673 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-01-20 06:46:20,673 : INFO : EPOCH - 5 : training on 1453943 raw words (1358527 effective words) took 3.7s, 366096 effective words/s
# 2022-01-20 06:46:20,675 : INFO : training on a 7269715 raw words (6792635 effective words) took 18.7s, 363380 effective words/s

# %% [markdown]
# ##  Training result

# %%
skip_gram.wv.most_similar("man") # skip-gram 모델을 이용하여 'man'에 가장 유사한 단어 추출
# Out:
# 2022-01-20 06:46:20,682 : INFO : precomputing L2-norms of word weight vectors
# [('woman', 0.7501734495162964),
#  ('boy', 0.7098569869995117),
#  ('person', 0.6910547018051147),
#  ('teenager', 0.682701826095581),
#  ('doctor', 0.6757025718688965),
#  ('girl', 0.6706797480583191),
#  ('guy', 0.667211651802063),
#  ('kid', 0.6545884609222412),
#  ('lady', 0.6518937349319458),
#  ('einstein', 0.6498644351959229)]

# %%
CBOW.wv.most_similar("man") # CBOW 모델을 이용하여 'man'에 가장 유사한 단어 추출
# Out:
# 2022-01-20 06:46:20,710 : INFO : precomputing L2-norms of word weight vectors
# [('woman', 0.9341150522232056),
#  ('girl', 0.9114941358566284),
#  ('boy', 0.8791621923446655),
#  ('child', 0.8152865171432495),
#  ('kid', 0.7914962768554688),
#  ('doctor', 0.7842838764190674),
#  ('guy', 0.7682653665542603),
#  ('secret', 0.7668085694313049),
#  ('person', 0.7637799978256226),
#  ('lawyer', 0.7545815110206604)]

# %%
vector = skip_gram["king"] - skip_gram["man"] + skip_gram["women"]
skip_gram.wv.similar_by_vector(vector, topn=10, restrict_vocab=None)
# Out:
# [('king', 0.6175812482833862),
#  ('veterans', 0.5925766229629517),
#  ('politicians', 0.573754072189331),
#  ('fighters', 0.5651514530181885),
#  ('screenwriters', 0.5628189444541931),
#  ('coen', 0.5620450973510742),
#  ('exotic', 0.5565236806869507),
#  ('interactions', 0.5556589961051941),
#  ('leaders', 0.5523719787597656),
#  ('hitmen', 0.5521821975708008)]

# %%
feat = skip_gram['man']
print(len(feat))
# Out:
# 300

# %%
def render_TSNE(vocab, word_emb):
    """
    TSNE를 이용한 word2vec 시각화 
    args:
        vocab    - vocab list
        word_emb - word embeddings
    """
    tsne = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32) #TSNE 시각화를 위한 initialization
    _tsne = tsne.fit_transform(word_emb) # TSNE 시각화 적용
    x_coordinate = _tsne[:,0] # x 좌표
    y_coordinate = _tsne[:,1] # y 좌표

    # scatter plot initialization
    fig, ax = plt.subplots()
    fig.set_size_inches(40, 20)
    ax.scatter(x_coordinate, y_coordinate)

    for i, word in enumerate(random_vocab):
        ax.annotate(word,(x_coordinate[i], y_coordinate[i]), fontsize=30) # 각 scatter들에대해 단어 labeling

    plt.show()

# %%
# Skip-gram 시각화(TSNE)
vocab = list(skip_gram.wv.vocab) # vocab list 불러오기
random_vocab = random.sample(vocab,k=100) #100개의 임의 단어를 랜덤 샘플링
word_emb = skip_gram[random_vocab] # 샘플링된 단어에 대해 학습된 임베딩 벡터 불러오기
render_TSNE(random_vocab, word_emb) # TSNE 시각화

# %%
# CBOW 시각화(TSNE)
vocab = list(CBOW.wv.vocab) # vocab list 불러오기
random_vocab = random.sample(vocab,k=100) #100개의 임의 단어를 랜덤 샘플링
word_emb = skip_gram[random_vocab] # 샘플링된 단어에 대해 학습된 임베딩 벡터 불러오기
render_TSNE(random_vocab, word_emb) # TSNE 시각화

# %% [markdown]
# # Chapter2

# %% [markdown]
# # Lanaguage Model (RNN)

# %% [markdown]
# ![대체 텍스트](./figures/lm_1.jpg)

# %%
def build_dict(seqs):
    num_skip_sent = 0
    word_count = 4
    vocab = ["<pad>","<s>","</s>","<unk>"]
    word2id = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3}
    id2word = {0: "<pad>", 1: "<s>", 2: "</s>", 3: "<unk>"}
    print("Building vocab and dict..")
    for line in seqs:
        words = line.strip().split(' ') # tokenized by space 
        for word in words:
            if word not in vocab:
                word_count += 1 # increment word_count
                vocab.append(word) # append new unique word
                index = word_count - 1 # word index (consider index 0)
                word2id[word] = index # word to index
                id2word[index] = word # index to word
    
    print("Number of unique words: %d" % len(vocab))
    print("Finised building vocab and dict!")

    return vocab, word2id, id2word

# %%
# Training corpus를 사용하여 vocab과 dict 구성
assert os.path.isfile(os.path.join(data_path, "lm_data/pos/train.txt"))
assert os.path.isfile(os.path.join(data_path, "lm_data/neg/train.txt"))
pos_seqs = open(os.path.join(data_path, "lm_data/pos/train.txt")).readlines()
neg_seqs = open(os.path.join(data_path, "lm_data/neg/train.txt")).readlines()
seqs = pos_seqs + neg_seqs # 긍정 corpus + 부정 corpus

# %%
print(seqs[1])
# Out:
# for starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid '80s with a 12-part series called the watchmen .

# %%
# Building vocab or loading existing vocab
path = os.path.join(data_path, "lm_id2word.pkl")
if os.path.isfile(path):
    with open(os.path.join(data_path, "lm_id2word.pkl"), "rb") as f:
        id2word = pickle.load(f)
    with open(os.path.join(data_path, "lm_word2id.pkl"), "rb") as f:
        word2id = pickle.load(f)
    with open(os.path.join(data_path, "lm_vocab.pkl"), "rb") as f:
        vocab = pickle.load(f)

else:
    vocab, word2id, id2word = build_dict(seqs)
    pickle.dump(vocab, open(os.path.join(data_path, "lm_vocab.pkl"), "wb" ))
    pickle.dump(word2id, open(os.path.join(data_path, "lm_word2id.pkl"), "wb" ))
    pickle.dump(id2word, open(os.path.join(data_path, "lm_id2word.pkl"), "wb" ))

# %%
# example of first 10 word2id
for index, word in enumerate(word2id.keys()):
    print({word: word2id[word]})
    if index == 9:
        break
# Out:
# {'<pad>': 0}
# {'<s>': 1}
# {'</s>': 2}
# {'<unk>': 3}
# {'films': 4}
# {'adapted': 5}
# {'from': 6}
# {'comic': 7}
# {'books': 8}
# {'have': 9}

# %%
# example of first 10 id2word
for index, id in enumerate(id2word.keys()):
    print({id: id2word[id]})
    if index == 9:
        break
# Out:
# {0: '<pad>'}
# {1: '<s>'}
# {2: '</s>'}
# {3: '<unk>'}
# {4: 'films'}
# {5: 'adapted'}
# {6: 'from'}
# {7: 'comic'}
# {8: 'books'}
# {9: 'have'}

# %%
class LM_Dataset(data.Dataset):

    def __init__(self, pos_path, neg_path , word2id):
        
        #(add+)
        self.pos_seqs = open(pos_path).readlines()
        self.pos_labels = [0] * len(self.pos_seqs)
        self.neg_seqs = open(neg_path).readlines()
        self.neg_labels = [1] * len(self.neg_seqs)
        self.seqs = self.pos_seqs + self.neg_seqs # concat pos_seqs and neg_seqs
        self.labels = self.pos_labels + self.neg_labels
        
        self.word2id = word2id


    def __getitem__(self, index): # 가장 중요한 part Dataset 을 상속한 클래스는 이 부분을 overriding 해줘야함. 
        """Returns one data pair (source and sentiment)."""
        seqs = self.seqs[index]
        seqs = self.process(seqs, self.word2id)
        sentiment_labels = self.labels[index]
        return seqs, sentiment_labels

    def __len__(self): # 필수적인 클래스 이 부분을 무조건 overriding 해야함 
        return len(self.seqs) # 데이터 갯수 return 
                    
    def process(self, seq, word2id):
        sequence = []
        sequence.append(word2id["<s>"])
        words = seq.strip().split(' ')
        if len(words) <= 250: # max seq_len = 100
            for word in words:
                if word in word2id:
                    sequence.append(word2id[word]) # 
                else:
                    sequence.append(3) # replace by <unk> token
        sequence.append(word2id["</s>"])
        sequence = torch.Tensor(sequence)
        return sequence

# %% [markdown]
# ### Batch 를 구성해보겠습니다.
# Q : 우리의 문장에서 항상 단어의 갯수는 일정한가요?
#
# 문제점: Tensor로 변환하기 위해서는 추가 처리 필요 . eg. Sentence1 : W1 , W2, W3 ,W4 / Sentence : W1 , W2 ,W3 ->  2*3이 맞나요? 2*4가 맞나요?
#
# 해결법 : Batch * max_length  Tensor로 변환합니다. eg. 2*4의 경우 2 번째 문장의 마지막에 PAD_token을 처리해줍니다. Index 보통 : 0

# %%
def batch(iterable, n=1):
    args = [iter(iterable)] * n
    return zip_longest(*args)


def pad_tensor(vec, pad, value=0, dim=0):
    """
    pad token으로 채우는 용도 
    args:
        vec - tensor to pad
        pad - the size to pad to
        dim - dimension to pad
    return:
        a new tensor padded to 'pad' in dimension 'dim'
    """
    pad_size = pad - vec.shape[0]

    if len(vec.shape) == 2:
        zeros = torch.ones((pad_size, vec.shape[-1])) * value
    elif len(vec.shape) == 1:
        zeros = torch.ones((pad_size,)) * value
    else:
        raise NotImplementedError
    return torch.cat([torch.Tensor(vec), zeros], dim=dim)

# %% [markdown]
# ![대체 텍스트](./figures/sorted.jpg)

# %%
def collate_fn(batch, values=(0, 0), dim=0):
    """
    데이터 로더에 들어가기전에 batch화 할 때 거치는 함수 
    args:
        batch - list of (tensor, label)
    reutrn:
        xs - a tensor of all examples in 'batch' after padding
        ys - a LongTensor of all labels in batch
        ws - a tensor of sequence lengths
    """

    sequence_lengths = torch.Tensor([int(x[0].shape[dim]) for x in batch]) # 각 batch 마다 길이를 얻어내고 
    sequence_lengths, xids = sequence_lengths.sort(descending=True) # 감소하는 순서로 정렬
    # find longest sequence (가장 긴 sequence의 길이를 구함 )
    max_len = max(map(lambda x: x[0].shape[dim], batch))
    # pad according to max_len (max length 만큼 padd를 추가 )
    batch = [(pad_tensor(x, pad=max_len, dim=dim), label) for (x, label) in batch]

    # stack all
    xs = torch.stack([x[0] for x in batch], dim=0)
    xs = xs[xids].contiguous() # decreasing order로 다시 나열
    
    labels = [x[1] for x in batch]
    labels = [labels[i] for i in xids] # decreasing order로 다시 나열
    
    return xs.long(), sequence_lengths.int(), torch.Tensor(labels)

# %% [markdown]
# ### Build Language model

# %% [markdown]
# ### Example  pack padded

# %%
a = [torch.tensor([1,2,3]), torch.tensor([3,4])]
b = torch.nn.utils.rnn.pad_sequence(a, batch_first=True)
b
# Out:
# tensor([[1, 2, 3],
#         [3, 4, 0]])

# %%
pack_b=torch.nn.utils.rnn.pack_padded_sequence(b, batch_first=True, lengths=[3,2])
pack_b
# Out:
# PackedSequence(data=tensor([1, 3, 2, 4, 3]), batch_sizes=tensor([2, 2, 1]), sorted_indices=None, unsorted_indices=None)

# %%
rnn_utils.pad_packed_sequence(pack_b,batch_first=True,padding_value=0.)
# Out:
# (tensor([[1, 2, 3],
#          [3, 4, 0]]), tensor([3, 2]))

# %% [markdown]
# ## Model

# %%
class LM(nn.Module):
    def __init__(self, config, vocab_size):
        super(LM, self).__init__()
        self.vocab_size = vocab_size # get vocabulary size 
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"])  # initialize embedding layer 
        self.rnn = nn.RNN(input_size=config["embedding_size"], hidden_size=config["hidden_size"], 
                          dropout=config["dropout"], batch_first=True) # defined rnn layer 
        self.outputs2vocab = nn.Linear(config["hidden_size"], self.vocab_size) # linear layer to predict the sentiment
    def forward(self, input, lengths):
        # ---------------- fill in ------------------------ 
        batch_size = input.size(0)  # get batch_size
        input_embedding = self.embedding(input) # embedding layer  (B,L) -> (B,L ,hidden)
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True) # pack sequence 
        outputs, _ = self.rnn(packed_input) # rnn 
        padded_outputs = rnn_utils.pad_packed_sequence(outputs, batch_first=True, padding_value=0.)[0] # packed sequence 
        padded_outputs = padded_outputs.contiguous()
        outputs = self.outputs2vocab(padded_outputs)
        logits = outputs.contiguous().view(-1, self.vocab_size)
        # ---------------- fill in ------------------------ 
        return logits

# %%
config = {
  "epochs": 3,
  "hidden_size": 64,
  "decoder_layers": 1,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
train_dataset = LM_Dataset(os.path.join(data_path, "lm_data/pos/train.txt"), os.path.join(data_path, "lm_data/neg/train.txt"), word2id)
train_data_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)

valid_dataset = LM_Dataset(os.path.join(data_path, "lm_data/pos/valid.txt"), os.path.join(data_path, "lm_data/neg/valid.txt"), word2id)
valid_data_loader = torch.utils.data.DataLoader(dataset=valid_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=False,
                                          collate_fn=collate_fn)
test_dataset = LM_Dataset(os.path.join(data_path, "lm_data/pos/test.txt"), os.path.join(data_path, "lm_data/neg/test.txt"), word2id)
test_data_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=False,
                                          collate_fn=collate_fn)

# %%
def lm_train(model, optimizer, train_loader, epoch,n_epochs):
    
    losses = []

    model.train() # train mode
    n_iter = 0
    for batch in train_loader:
        input, input_lengths, _ = batch 
        
        output = model(input[:,:-1].contiguous().to(device),(input_lengths-1))
        loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0).to(device)
        
        target = input[:,1:].contiguous().view(-1) 
        
        loss = loss_fn(output,target.to(device))
        losses.append(loss.item())
        # ------------------ fill in -------------------
        # Reset gradients
        optimizer.zero_grad()
        # Compute gradients
        loss.backward()
        # step optimzier 
        optimizer.step()
        # ------------------ fill in -------------------
        n_iter+=1 # count number of trained sentences
        if n_iter % 100 == 0: # print loss info for every 100 iteration steps
            print ('\n [{}] current_iter_loss= {:05.3f}'.format(n_iter,loss))
  
    print ('\n Epoch({}/{}) avg_loss= {:05.3f}'.format(epoch+1,n_epochs,np.mean(losses)))
    
    return model, optimizer

# %%
def lm_eval(model, loader):
    losses = []

    model.eval() # valid mode
    n_iter = 0
 
    for batch in loader:
        input, input_lengths, _ = batch
        output = model(input[:,:-1].contiguous().to(device),(input_lengths-1))
        loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0).to(device)
        target = input[:,1:].contiguous().view(-1)
        loss = loss_fn(output,target.to(device))
        losses.append(loss.item())
    
    return losses

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LM(config, vocab_size=len(vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = lm_train(model.to(device),optimizer, train_data_loader, epoch,config["epochs"]) # train
    valid_loss = lm_eval(model.to(device), valid_data_loader) # valid
    print ('\n              avg_valid loss= {:05.3f}'.format(np.mean(valid_loss)))
    test_loss = lm_eval(model.to(device), test_data_loader) # test
    print ('\n              avg_test loss= {:05.3f}'.format(np.mean(test_loss)))
# Out:
#  [100] current_iter_loss= 6.996
#
#  [200] current_iter_loss= 6.669
#
#  [300] current_iter_loss= 6.592
#
#  [400] current_iter_loss= 6.636
#
#  [500] current_iter_loss= 6.437
#
#  [600] current_iter_loss= 6.097
#
#  [700] current_iter_loss= 6.225
#
#  [800] current_iter_loss= 6.408
#
#  [900] current_iter_loss= 6.116
#
#  [1000] current_iter_loss= 5.993
#
#  [1100] current_iter_loss= 6.139
#
#  [1200] current_iter_loss= 5.995
#
#  [1300] current_iter_loss= 6.266
#
#  [1400] current_iter_loss= 5.856
#
#  [1500] current_iter_loss= 5.989
#
#  [1600] current_iter_loss= 5.838
#
#  [1700] current_iter_loss= 6.117
#
#  [1800] current_iter_loss= 5.921
#
#  [1900] current_iter_loss= 5.894
#
#  Epoch(1/3) avg_loss= 6.343
#
#               avg_valid loss= 5.860
#
#               avg_test loss= 5.717
#
#  [100] current_iter_loss= 5.825
#
#  [200] current_iter_loss= 5.682
#
#  [300] current_iter_loss= 5.834
#
#  [400] current_iter_loss= 5.722
#
#  [500] current_iter_loss= 5.694
#
#  [600] current_iter_loss= 5.800
#
#  [700] current_iter_loss= 5.905
#
#  [800] current_iter_loss= 5.486
#
#  [900] current_iter_loss= 5.848
#
#  [1000] current_iter_loss= 5.653
#
#  [1100] current_iter_loss= 5.730
#
#  [1200] current_iter_loss= 5.737
#
#  [1300] current_iter_loss= 5.623
#
#  [1400] current_iter_loss= 5.771
#
#  [1500] current_iter_loss= 5.896
#
#  [1600] current_iter_loss= 5.690
#
#  [1700] current_iter_loss= 5.471
#
#  [1800] current_iter_loss= 5.637
#
#  [1900] current_iter_loss= 5.753
#
#  Epoch(2/3) avg_loss= 5.709
#
#               avg_valid loss= 5.703
#
#               avg_test loss= 5.497
#
#  [100] current_iter_loss= 5.478
#
#  [200] current_iter_loss= 5.365
#
#  [300] current_iter_loss= 5.523
#
#  [400] current_iter_loss= 5.425
#
#  [500] current_iter_loss= 5.464
#
#  [600] current_iter_loss= 5.567
#
#  [700] current_iter_loss= 5.531
#
#  [800] current_iter_loss= 5.290
#
#  [900] current_iter_loss= 5.285
#
#  [1000] current_iter_loss= 5.248
#
#  [1100] current_iter_loss= 5.632
#
#  [1200] current_iter_loss= 5.542
#
#  [1300] current_iter_loss= 5.448
#
#  [1400] current_iter_loss= 5.516
#
#  [1500] current_iter_loss= 5.368
#
#  [1600] current_iter_loss= 5.298
#
#  [1700] current_iter_loss= 5.775
#
#  [1800] current_iter_loss= 5.605
#
#  [1900] current_iter_loss= 5.452
#
#  Epoch(3/3) avg_loss= 5.480
#
#               avg_valid loss= 5.631
#
#               avg_test loss= 5.410

# %% [markdown]
# ### Layer 를 더 깊게

# %%
config = {
  "epochs": 1,
  "hidden_size": 64,
  "decoder_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LM(config, vocab_size=len(vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = lm_train(model.to(device),optimizer, train_data_loader, epoch,config["epochs"]) # train
    valid_loss = lm_eval(model.to(device), valid_data_loader) # valid
    print ('\n              avg_valid loss= {:05.3f}'.format(np.mean(valid_loss)))
    test_loss = lm_eval(model.to(device), test_data_loader) # test
    print ('\n              avg_test loss= {:05.3f}'.format(np.mean(test_loss)))
# Out:
#  [100] current_iter_loss= 6.851
#
#  [200] current_iter_loss= 6.831
#
#  [300] current_iter_loss= 6.652
#
#  [400] current_iter_loss= 6.632
#
#  [500] current_iter_loss= 6.486
#
#  [600] current_iter_loss= 6.228
#
#  [700] current_iter_loss= 6.338
#
#  [800] current_iter_loss= 6.112
#
#  [900] current_iter_loss= 6.289
#
#  [1000] current_iter_loss= 6.061
#
#  [1100] current_iter_loss= 6.171
#
#  [1200] current_iter_loss= 5.989
#
#  [1300] current_iter_loss= 6.053
#
#  [1400] current_iter_loss= 6.221
#
#  [1500] current_iter_loss= 6.158
#
#  [1600] current_iter_loss= 5.877
#
#  [1700] current_iter_loss= 5.975
#
#  [1800] current_iter_loss= 6.373
#
#  [1900] current_iter_loss= 6.084
#
#  Epoch(1/1) avg_loss= 6.351
#
#               avg_valid loss= 5.867
#
#               avg_test loss= 5.731

# %% [markdown]
# ### GRU로 변경하기

# %%
class LM(nn.Module):
    def __init__(self, config, vocab_size):
        super(LM, self).__init__()
        self.vocab_size = vocab_size # get vocabulary size 
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"])  # initialize embedding layer 
        # ------------------------- fill in --------------------------------
        self.rnn = nn.GRU(input_size=config["embedding_size"], hidden_size=config["hidden_size"], 
                          dropout=config["dropout"], batch_first=True) # defined rnn layer 
        self.outputs2vocab = nn.Linear(config["hidden_size"], self.vocab_size) # linear layer to predict the sentiment
        # ------------------------- fill in --------------------------------
    def forward(self,input, lengths):
        batch_size = input.size(0) # get batch_size
        input_embedding = self.embedding(input) # embedding layer  (B,L) -> (B,L ,hidden)
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True) # pack sequence 
        outputs, _ = self.rnn(packed_input)   # rnn 
        padded_outputs = rnn_utils.pad_packed_sequence(outputs, batch_first=True, padding_value=0.)[0] # packed sequence 
        padded_outputs = padded_outputs.contiguous()
        outputs = self.outputs2vocab(padded_outputs) 
        logits = outputs.contiguous().view(-1, self.vocab_size)
        return logits
# Out:
#   File "<ipython-input-84-fa9ae4a52f2b>", line 7
#     self.rnn =
#                ^
# SyntaxError: invalid syntax

# %%
config = {
  "epochs": 1,
  "hidden_size": 64,
  "decoder_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = LM(config, vocab_size=len(vocab))
optimizer = torch.optim.Adam(model.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = lm_train(model.to(device),optimizer, train_data_loader, epoch,config["epochs"]) # train
    valid_loss = lm_eval(model.to(device), valid_data_loader) # valid
    print ('\n              avg_valid loss= {:05.3f}'.format(np.mean(valid_loss)))
    test_loss = lm_eval(model.to(device), test_data_loader) # test
    print ('\n              avg_test loss= {:05.3f}'.format(np.mean(test_loss)))

# %% [markdown]
# # Chatper 3

# %% [markdown]
# # Sentiment Classfication

# %%
class Sentiment_Dataset(data.Dataset):

    def __init__(self, path , word2id):
        self.seqs = open(path).readlines() # sentences
        self.word2id = word2id # token : id (숫자)

    def __getitem__(self, index):
        """Returns one data pair (source and sentiment)."""
        seqs = self.seqs[index]
        seqs, label = self.process(seqs, self.word2id)
        return seqs, label

    def __len__(self):
        return len(self.seqs)
                    
    def process(self, seq, word2id):
        label = 0 # default label "pos"
        sequence = []
        sequence.append(word2id["<s>"])
        words = seq.strip().split(' ')
        for i in range(0, len(words)-1):
            current_word = words[i]
            if "negative" == words[len(words)-1]: #if label is "neg", then 1
                label = 1
            if current_word in word2id:
                sequence.append(word2id[current_word])
            else:
                sequence.append(3) # replace by <unk> token
        sequence.append(word2id["</s>"])
        sequence = torch.Tensor(sequence)
        return sequence, label

# %%
class Sentiment_Classification(nn.Module):
    """
    IMDb 영화 리뷰 감성분류 모델
    """
    def __init__(self, config, vocab_size):
        """
        args:
            config     - hyperparameters
            vocab_size - vocab_size
        return:
            None
        """
        super(Sentiment_Classification, self).__init__()
        self.vocab_size = vocab_size
        # ------------------------- fill in --------------------------------
        self.embedding = nn.Embedding(self.vocab_size, config['embedding_size'])# embedding layer 
        self.rnn = nn.RNN(input_size=config["embedding_size"], hidden_size=config["hidden_size"], 
                          num_layers=config["num_layers"],dropout=config["dropout"],bidirectional = config['bidirectional'] , batch_first=True)
        self.bidirectional = config['bidirectional']
        self.num_layers = config['num_layers']
        if self.bidirectional:
            self.hidden_size = 2 * config['hidden_size']
        else:
            self.hidden_size = config['hidden_size']
        self.outputs = nn.Sequential(
            # 3 layer mlp with LeakyReLU(0.2) in between, last activation is sigmoid
                        nn.Linear(self.hidden_size, self.hidden_size),
                        nn.LeakyReLU(0.2),
                        nn.Linear(self.hidden_size, self.hidden_size),
                        nn.LeakyReLU(0.2),
                        nn.Linear(self.hidden_size, 1),
                        nn.Sigmoid()
        )
        # ------------------------- fill in --------------------------------
    def forward(self,input, lengths):
        """
        args:
            input   - setences
            lengths - setence lengths
        return:
            outputs - positive or negative
        """
        # input -> 임베딩 -> packpadded -> rnn -> hidden_state -> linear -> classificaion 
        batch_size = input.size(0) 
        input_embedding = self.embedding(input) # 임베딩
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True) # pack_padded
        _, hidden = self.rnn(packed_input) # rnn

        if self.bidirectional:
            batch_size = hidden.size()[1]
            hidden = hidden.view(self.num_layers,2,batch_size,-1)
            hidden = hidden.permute(2,0,1,3).contiguous().view(batch_size,self.num_layers,-1)
        else:
            hidden = hidden.permute(1,0,2)
            
        hidden = hidden[:,-1,:]
        outputs = self.outputs(hidden)
        outputs = outputs.squeeze(1)
        return outputs

# %%
def sentiment_trainer(model, optimizer, loaders, epoch,n_epochs):
    """
    args:
        model     - sentiment model
        optimizer - adam
        loaders   - valid, train loaders
    return:
        model, optimizer
    """
    losses = []
    total_accuracy = []
    val_losses = []
    val_total_accuracy = []
    n_iter = 0
    for split in loaders.keys():
        if split == "train":
            for batch in loaders[split]:
        # ------------------------- fill in --------------------------------
                model.train() # train mode
                input, input_lengths, target_label = batch
                
                predict_label = model(input.to(device), input_lengths)

                loss_fn = nn.BCELoss().to(device)
                loss = loss_fn(predict_label, target_label.to(device))
                losses.append(loss.item())

                # Calculate accuracy
                x_acc = predict_label.round().cpu().detach().numpy()
                y_acc = target_label.cpu().detach().numpy()
                accuracy = accuracy_score(x_acc,y_acc)
                total_accuracy.append(accuracy)

                # Reset gradients
                optimizer.zero_grad()
                # Compute gradients
                loss.backward()
                # step
                optimizer.step()
        # ------------------------- fill in --------------------------------
                n_iter+=1 # count number of trained sentences
                if n_iter % 100 == 0: # print loss only if it's training stage
                    print ('\n [{}] current_iter_loss= {:05.3f} acc= {:05.3f}'.format(n_iter,loss,accuracy))
                
        elif split == "valid":
            model.eval() # eval mode
            for batch in loaders[split]:
                input, input_lengths, target_label = batch
                predict_label = model(input.to(device),input_lengths)
                loss_fn = nn.BCELoss().to(device)
                loss = loss_fn(predict_label,target_label.to(device))
                val_losses.append(loss.item())
                # Calculate accuracy
                x_acc = predict_label.round().cpu().detach().numpy()
                y_acc = target_label.cpu().detach().numpy()
                accuracy = accuracy_score(x_acc,y_acc)
                val_total_accuracy.append(accuracy)
  
    print ('\n Epoch({}/{}) avg train_loss= {:05.3f} train_acc= {:05.3f} val_loss= {:05.3f} val_acc= {:05.3f}'
           .format(
               epoch+1,n_epochs,np.mean(losses), np.mean(total_accuracy), 
                   np.mean(val_losses), np.mean(val_total_accuracy)
              )
          )
    
    return model, optimizer

# %%
def idx2word(idx, i2w, pad_idx):
    """
    index로 이루어진 문장을 받아,
    word 문장으로 전환
    """

    sent_str = [str()]*len(idx)

    for i, sent in enumerate(idx):

        for word_id in sent:

            if word_id == pad_idx:
                break
            sent_str[i] += i2w[int(word_id)] + " "

        sent_str[i] = sent_str[i].strip()


    return sent_str[0]

# %%
def evaluate(model, loader, epoch,n_epochs, id2word):
    """
    각 epoch 마다 model에 대한 test및, prediction결과 추출
    """
    losses = []
    total_accuracy = []
    model.eval()
    for batch in loader:
        input, input_lengths, target_label = batch
        predict_label = model(input.to(device),input_lengths)
        loss_fn = nn.BCELoss().to(device)
        loss = loss_fn(predict_label,target_label.to(device))
        losses.append(loss.item())
        # Calculate accuracy
        x_acc = predict_label.round().cpu().detach().numpy()
        y_acc = target_label.cpu().detach().numpy()
        accuracy = accuracy_score(x_acc,y_acc)
        total_accuracy.append(accuracy)

    print('\n Epoch({}/{}) avg test_loss= {:05.3f} test_acc= {:05.3f}'
        .format(epoch+1,n_epochs,np.mean(losses), np.mean(total_accuracy))
    )
    
    # test inference
    print(idx2word(input, id2word, 0))
    predict_label = model(input.to(device),input_lengths)
    ans = {0: 'positive', 1:'negative'}
    print('\n Pred: {}, Ans: {}'
          .format(ans[predict_label[0].round().item()], ans[target_label[0].item()])
         )

# %%
seqs = open(os.path.join(data_path, "lm_data/new_IMDb/train.tok")).readlines()
vocab, word2id, id2word = build_dict(seqs)
# Out:
# Building vocab and dict..
# Number of unique words: 119621
# Finised building vocab and dict!

# %%
# Building vocab or loading existing vocab
# path = "/content/drive/MyDrive/Colab Notebooks/yeardream/24._20220120_DAY23/drive-download-20220120T000210Z-001/실습2"
os.chdir('/content/drive/MyDrive/Colab Notebooks/yeardream/24._20220120_DAY23/drive-download-20220120T000210Z-001/실습2')
if os.path.isfile(path):
    with open("./Data/sentimen_id2word.pkl", "rb") as f:
        id2word = pickle.load(f)
    with open("./Data/sentimen_word2id.pkl", "rb") as f:
        word2id = pickle.load(f)
    with open("./Data/sentiment_vocab.pkl", "rb") as f:
        vocab = pickle.load(f)

else: # file does not exist
    vocab, word2id, id2word = build_dict(seqs)
    pickle.dump(vocab, open("./Data/sentiment_vocab.pkl", "wb" ))
    pickle.dump(word2id, open("./Data/sentiment_word2id.pkl", "wb" ))
    pickle.dump(id2word, open("./Data/sentiment_id2word.pkl", "wb" ))
# Out:
# Building vocab and dict..

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 3,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# constructing train dataset
train_dataset = Sentiment_Dataset(os.path.join(data_path, "lm_data/new_IMDb/train.tok"), word2id)
train_data_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)
# constructing valid dataset
valid_dataset = Sentiment_Dataset(os.path.join(data_path, "lm_data/new_IMDb/valid.tok"), word2id)
valid_data_loader = torch.utils.data.DataLoader(dataset=valid_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)
# constructing test dataset
test_dataset = Sentiment_Dataset("./Data/lm_data/new_IMDb/test.tok", word2id)
test_data_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=config["batch_size"],
                                          shuffle=True,
                                          collate_fn=collate_fn)

loaders = {"train": train_data_loader, "valid": valid_data_loader}

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Init sentiment model
model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.712 acc= 0.469
#
#  [200] current_iter_loss= 0.671 acc= 0.562
#
#  [300] current_iter_loss= 0.614 acc= 0.688
#
#  [400] current_iter_loss= 0.758 acc= 0.562
#
#  [500] current_iter_loss= 0.501 acc= 0.719
#
#  [600] current_iter_loss= 0.550 acc= 0.656
#
#  [700] current_iter_loss= 0.500 acc= 0.719
#
#  [800] current_iter_loss= 0.316 acc= 0.875
#
#  [900] current_iter_loss= 0.363 acc= 0.844
#
#  Epoch(1/5) avg train_loss= 0.506 train_acc= 0.729 val_loss= 0.341 val_acc= 0.851
#
#  Epoch(1/5) avg test_loss= 0.348 test_acc= 0.853
# <s> " I was amazingly impressed by this movie . It contained fundamental elements of depression , grief , loneliness , despair , hope , dreams and companionship . It wasn 't merely about a genius musician who hit rock bottom but it was about a man caught up in grief trying drastically to find solace within his music . He finds a companion who comes with her own issues . Claire and Des were able to provide each other with friendship and love but more importantly a conclusion to events which had shaped their life for the worst . Des is an unlikely character by todays standards of a rock star . Yet he has musical genius . He also has an event in his past that has made him <unk> , while things around him literally go to ruins . His focus is creating his Whale Music , in fact it becomes an obsession for <unk> is the streetwise kid that needs a place to stay . She finds hidden talents while being in Des company . She also finds a mutual friend that accepts her . She learns to trust him over a period of <unk> two find love with one another . Not the mind blowing , sex infused kind of passion , but a love where friendship and understanding means more . For two people who have been hurt , they find trust together . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.245 acc= 0.938
#
#  [200] current_iter_loss= 0.219 acc= 0.938
#
#  [300] current_iter_loss= 0.186 acc= 0.875
#
#  [400] current_iter_loss= 0.279 acc= 0.938
#
#  [500] current_iter_loss= 0.158 acc= 0.906
#
#  [600] current_iter_loss= 0.231 acc= 0.906
#
#  [700] current_iter_loss= 0.217 acc= 0.844
#
#  [800] current_iter_loss= 0.307 acc= 0.844
#
#  [900] current_iter_loss= 0.202 acc= 0.906
#
#  Epoch(2/5) avg train_loss= 0.263 train_acc= 0.892 val_loss= 0.272 val_acc= 0.880
#
#  Epoch(2/5) avg test_loss= 0.286 test_acc= 0.875
# <s> " Where do I start . Lets list the good things about this movie <unk> <unk> Persbrandt is great as the Gangster Thomas . This is the only character you will actually care about , and he 's a bad guy ! ( <unk> never does anything bad , and is generally a pretty likable guy ) 2 . <unk> <unk> is always great . He 's a bit toned down here , but he is quite funny still 3 . The movie looked pretty good by Swedish standards , good use of depth of field and <unk> the bad . This is by far the worst script to make it into the big screen ever . The acting by everyone else was pretty bad and over the top . The direction was horrible . A totally meaningless story , totally unrealistic characters and events and 1.5 hours to long . During emotional scenes pretty much everyone in the theater laughed . People just started walking out during the course of the screening . There 's no way to actually summarize the story into something coherent , so I wont even try . Every clich챕 ever conceived is in there , and in all the wrong places . I 'm sorry to say this is one of the worst movies I have ever seen in my entire life . Watch it for a good laugh , but try not to pay any money for it ; ) <unk> , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.186 acc= 0.938
#
#  [200] current_iter_loss= 0.106 acc= 0.969
#
#  [300] current_iter_loss= 0.087 acc= 0.969
#
#  [400] current_iter_loss= 0.280 acc= 0.938
#
#  [500] current_iter_loss= 0.526 acc= 0.875
#
#  [600] current_iter_loss= 0.053 acc= 0.969
#
#  [700] current_iter_loss= 0.155 acc= 0.938
#
#  [800] current_iter_loss= 0.118 acc= 0.938
#
#  [900] current_iter_loss= 0.200 acc= 0.938
#
#  Epoch(3/5) avg train_loss= 0.170 train_acc= 0.936 val_loss= 0.262 val_acc= 0.886
#
#  Epoch(3/5) avg test_loss= 0.303 test_acc= 0.879
# <s> " Long trailer ? whoever said that has got to be <unk> this has got to be one of the most in depth behind the scenes or making of documentary ever made. how can it be a trailer when several minutes are spent telling the audience how the movie was conceptualized and then brought to the studios ? this documentary also spends lots and lots of time detailing how stunts were done and the new technologies created to achieve them. then it shows us how woo ping 's team came up with the fight scenes along with blocking tapes that pretty much put to shame the actual scenes with the actors. there is stuff mentioned about matrix <unk> , but there 's hardly anything really. if you are a real fan of the matrix , you have to see this documentary. the original documentary in the dvd is good , but incomplete compared to this one. for instance , it never explained why <unk> wore a neck brace in the original documentary , but that is explained in <unk> the Revisited dvd also shows <unk> ann <unk> <unk> her ankle during the lobby scene and being really distraught because she feels like she 's letting the crew down. and that 's just the tip of the <unk> so ignore that " " just a long trailer " " review and go check it out for yourself. you won 't regret it. casual matrix fans need not apply ... , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.104 acc= 0.938
#
#  [200] current_iter_loss= 0.050 acc= 1.000
#
#  [300] current_iter_loss= 0.177 acc= 0.938
#
#  [400] current_iter_loss= 0.061 acc= 1.000
#
#  [500] current_iter_loss= 0.216 acc= 0.906
#
#  [600] current_iter_loss= 0.058 acc= 0.969
#
#  [700] current_iter_loss= 0.189 acc= 0.969
#
#  [800] current_iter_loss= 0.054 acc= 0.969
#
#  [900] current_iter_loss= 0.088 acc= 0.969
#
#  Epoch(4/5) avg train_loss= 0.102 train_acc= 0.964 val_loss= 0.263 val_acc= 0.889
#
#  Epoch(4/5) avg test_loss= 0.322 test_acc= 0.892
# <s> " Originally I rented this film for my daughter since she is keen on soccer - and I was not disappointed that way ( except the plot interfered with the soccer scenes ) . As a dad I suppose I was a little surprised at the introduction of the topic of lesbianism - but I have to admit that as a parent these issues are completely available to children nowadays ( as uncomfortable as I feel with the topic ) . In a way this emotion was a <unk> right into the main premise of the film - that at some age you must trust your children to make their own choices . This dilemma is introduced by a young <unk> teen girl - <unk> ( Jess ) - of <unk> heritage who dreams of playing professional soccer . The pending marriage of her older sister in a traditional Hindu marriage provides many rich opportunities for her to explore ( in a nice way ) her hopes and fears for her future . The multi-cultural challenge was a very interesting technique to explore Jess 's frustration with her parents expectations for her - again no different in substance than most <unk> relationships . In <unk> , the soccer scenes are GREAT ( lots to learn in <unk> ) and while I didn 't need the storyline - something was needed to keep the movie going . , " </s>
#
#  Pred: negative, Ans: positive
#
#  [100] current_iter_loss= 0.004 acc= 1.000
#
#  [200] current_iter_loss= 0.167 acc= 0.969
#
#  [300] current_iter_loss= 0.011 acc= 1.000
#
#  [400] current_iter_loss= 0.011 acc= 1.000
#
#  [500] current_iter_loss= 0.101 acc= 0.938
#
#  [600] current_iter_loss= 0.058 acc= 0.969
#
#  [700] current_iter_loss= 0.211 acc= 0.969
#
#  [800] current_iter_loss= 0.085 acc= 0.938
#
#  [900] current_iter_loss= 0.082 acc= 0.969
#
#  Epoch(5/5) avg train_loss= 0.055 train_acc= 0.982 val_loss= 0.312 val_acc= 0.892
#
#  Epoch(5/5) avg test_loss= 0.383 test_acc= 0.875
# <s> " That Certain Thing is the story of a gold digger ( Viola Dana ) from a tenement house . Her mother uses her to take care of her two brothers , but they are a loving family . Although Dana 's character has the opportunity to marry a streetcar conductor , she refuses and holds out for a millionaire . Everyone makes fun of her for her fantasy , but are surprised when one day she really does meet a millionaire , son of the owner of the popular ABC restaurant chain . The two marry hastily , but the girl 's dreams of wealth are shattered when the rich father <unk> his son for marrying a gold digger . However , she truly loves her new husband and the two are unexpectedly successful at making it on their own.A rare glimpse of movie star Viola Dana , this film is a lot of fun . Dana 's role is accessible , natural , and entertaining . She displays a knack for comedy as well as an ability to do drama.The mechanics of the film are a lot of fun too . The camera displays sophisticated late silent techniques like mobility . The title cards are also incredibly <unk> you like films like My Best Girl , It , or The Patsy , you will enjoy this film . , " </s>
#
#  Pred: positive, Ans: positive

# %% [markdown]
# ## No Bidirectional

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 2,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.707 acc= 0.500
#
#  [200] current_iter_loss= 0.829 acc= 0.562
#
#  [300] current_iter_loss= 0.666 acc= 0.656
#
#  [400] current_iter_loss= 0.572 acc= 0.688
#
#  [500] current_iter_loss= 0.417 acc= 0.844
#
#  [600] current_iter_loss= 0.386 acc= 0.844
#
#  [700] current_iter_loss= 0.298 acc= 0.844
#
#  [800] current_iter_loss= 0.265 acc= 0.875
#
#  [900] current_iter_loss= 0.471 acc= 0.844
#
#  Epoch(1/5) avg train_loss= 0.506 train_acc= 0.729 val_loss= 0.325 val_acc= 0.853
#
#  Epoch(1/5) avg test_loss= 0.341 test_acc= 0.855
# <s> " I see people writing about how great this movie was . It was horrible ! The acting was sub-par at best . It made a lot of money because teenage girls went to see the movie 7 times in the theaters because of Leonardo . Where the hell did they get the money ? Anyway , I wanted to learn more about the Titanic ; why it sank , what was running through a lot of people 's minds ; maybe even a little conspiracy stuff . Does anyone realize that certain people didn 't even board the ship because there was a fire on board before it even took off ? No , you don 't because all you see is a rich girl falling for a poor boy and he paints her naked ( did that corny junk at least tip you off that the movie was stupid ? ) .I did cry in during one scene , though . The scene when they showed the water that was filling up in the ship . It looked like pool water ! I 'm thinking this movie made all this money and they couldn 't even make the water from the ocean look real ? unbelievable ... Ohhh the band played on while the ship sank .. Just ridiculous . This was the worst movie until Pearl Harbor outdid it in the " " Nothing to Do With Reality " " department . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.178 acc= 0.875
#
#  [200] current_iter_loss= 0.373 acc= 0.875
#
#  [300] current_iter_loss= 0.317 acc= 0.875
#
#  [400] current_iter_loss= 0.074 acc= 0.969
#
#  [500] current_iter_loss= 0.398 acc= 0.875
#
#  [600] current_iter_loss= 0.264 acc= 0.844
#
#  [700] current_iter_loss= 0.234 acc= 0.938
#
#  [800] current_iter_loss= 0.236 acc= 0.969
#
#  [900] current_iter_loss= 0.228 acc= 0.906
#
#  Epoch(2/5) avg train_loss= 0.253 train_acc= 0.897 val_loss= 0.258 val_acc= 0.897
#
#  Epoch(2/5) avg test_loss= 0.295 test_acc= 0.874
# <s> " I claim no matter how hard I seek I 'll never find a better movie version of " " Othello " . " If you love Kenneth Branagh 's magnificent masterpieces " " Much ado about nothing " " ( 1993 ) and " " Hamlet " " ( 1996 ) as much as I do I 'm dead certain you 'll also find Oliver Parker 's " " Othello " " irresistible . Laurence Fishburne has been in a various splendid roles during his career . He was quite terrific in " " Boys n the hood " " ( 1991 ) - I 've always considered his amusing role of Furious <unk> as his very greatest achievement . That was , of course , way before I saw <unk> plays the part of Othello and he is probably in the most challenging role of his whole career but he does a brilliant , fantastic job . Ir챔ne Jacob is absolutely charming Desdemona and Kenneth Branagh is just simply phenomenal in a most fascinating role of the story 's crooked , manipulate villain Iago . Marvelous " " Othello " " is part of the absolute elite among Shakespeare 's ingenious works . It deals with his favorite topics : <unk> , envy , <unk> and jealousy . This movie adaptation is certainly one of the finest films I 've seen that 's based on William Shakespeare 's plays . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.091 acc= 0.969
#
#  [200] current_iter_loss= 0.217 acc= 0.906
#
#  [300] current_iter_loss= 0.239 acc= 0.938
#
#  [400] current_iter_loss= 0.231 acc= 0.906
#
#  [500] current_iter_loss= 0.224 acc= 0.875
#
#  [600] current_iter_loss= 0.278 acc= 0.938
#
#  [700] current_iter_loss= 0.086 acc= 0.938
#
#  [800] current_iter_loss= 0.251 acc= 0.906
#
#  [900] current_iter_loss= 0.266 acc= 0.875
#
#  Epoch(3/5) avg train_loss= 0.167 train_acc= 0.937 val_loss= 0.293 val_acc= 0.874
#
#  Epoch(3/5) avg test_loss= 0.332 test_acc= 0.870
# <s> " This is without doubt the best documentary ever produced giving an accurate and epic depiction of World War 2 from the invasion of Poland in 1939 to the end of the war in <unk> and to the point , this documentary presents views from both sides of the conflict giving a very human face to the war . At the same time tactics and the importance of <unk> are not overlooked , much work has been put into the giving a detailed picture of the war and in particularly the high , low and turning points in the allies fortunes . Being a British produced documentary this 26 part series focus is mainly on Britain , but Russia and America 's contribution are not skimmed over this is but one such advantage of a series of such <unk> worthy mention is the score , the music and the whole feel of the documentary is one of turmoil , struggle and perseverance . Like a film this series leaves the viewer in no doubt of the hardship faced by the allies and the Germans during the war , its build to a climax at the end of every episode , which serves to layer the coarse of the second world war . After watching all 26 the viewer is left with an extensive knowledge about the war and astonished at just how much we owe to the members of the previous generation . , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.099 acc= 0.938
#
#  [200] current_iter_loss= 0.016 acc= 1.000
#
#  [300] current_iter_loss= 0.023 acc= 1.000
#
#  [400] current_iter_loss= 0.207 acc= 0.906
#
#  [500] current_iter_loss= 0.020 acc= 1.000
#
#  [600] current_iter_loss= 0.044 acc= 0.969
#
#  [700] current_iter_loss= 0.079 acc= 0.969
#
#  [800] current_iter_loss= 0.119 acc= 0.969
#
#  [900] current_iter_loss= 0.077 acc= 0.969
#
#  Epoch(4/5) avg train_loss= 0.099 train_acc= 0.966 val_loss= 0.260 val_acc= 0.905
#
#  Epoch(4/5) avg test_loss= 0.325 test_acc= 0.877
# <s> " From around the time Europe began fighting World War II , until the war 's end , Hollywood ( with significant <unk> from the government ) made tons of movies which were designed to try and get young men to enlist in the Army , by making the life of a serviceman appear " " cool . " " This is by far the <unk> , implying that the life of a soldier is devoid of work , you get the best food , and you get to lie around all day listening to Ann Miller on the radio . I am far too young to have participated in WWII , but I think that there was more to it than that . There is the <unk> cat 's <unk> of a plot , and a bunch of musical numbers featuring some of the day 's leading <unk> think that by 1943 , even the most naive of <unk> knew that there was more going on overseas than the wacky hijinks portrayed in this movie . While I am sure that it was meant to be viewed as escapist entertainment , I can 't help but wonder if the family and loved ones of men fighting in the war , were amused or repulsed by this trivialization of their loved ones ' sacrifice . , " </s>
#
#  Pred: positive, Ans: negative
#
#  [100] current_iter_loss= 0.018 acc= 1.000
#
#  [200] current_iter_loss= 0.176 acc= 0.969
#
#  [300] current_iter_loss= 0.006 acc= 1.000
#
#  [400] current_iter_loss= 0.018 acc= 1.000
#
#  [500] current_iter_loss= 0.024 acc= 1.000
#
#  [600] current_iter_loss= 0.008 acc= 1.000
#
#  [700] current_iter_loss= 0.093 acc= 0.969
#
#  [800] current_iter_loss= 0.011 acc= 1.000
#
#  [900] current_iter_loss= 0.005 acc= 1.000
#
#  Epoch(5/5) avg train_loss= 0.054 train_acc= 0.983 val_loss= 0.287 val_acc= 0.908
#
#  Epoch(5/5) avg test_loss= 0.406 test_acc= 0.873
# <s> " This is without doubt the best documentary ever produced giving an accurate and epic depiction of World War 2 from the invasion of Poland in 1939 to the end of the war in <unk> and to the point , this documentary presents views from both sides of the conflict giving a very human face to the war . At the same time tactics and the importance of <unk> are not overlooked , much work has been put into the giving a detailed picture of the war and in particularly the high , low and turning points in the allies fortunes . Being a British produced documentary this 26 part series focus is mainly on Britain , but Russia and America 's contribution are not skimmed over this is but one such advantage of a series of such <unk> worthy mention is the score , the music and the whole feel of the documentary is one of turmoil , struggle and perseverance . Like a film this series leaves the viewer in no doubt of the hardship faced by the allies and the Germans during the war , its build to a climax at the end of every episode , which serves to layer the coarse of the second world war . After watching all 26 the viewer is left with an extensive knowledge about the war and astonished at just how much we owe to the members of the previous generation . , " </s>
#
#  Pred: positive, Ans: positive

# %% [markdown]
# ### GRU Model

# %%
class Sentiment_Classification(nn.Module):

    def __init__(self, config, vocab_size):
        super(Sentiment_Classification, self).__init__()
        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(self.vocab_size, config["embedding_size"])
        # ------------------------- fill in --------------------------------
        # create GRU model with args: input_size, hidden_size, num_layers, dropout, bidirectional, and batch_first=True
        self.rnn =nn.GRU(input_size=config["embedding_size"], hidden_size=config["hidden_size"], 
                          num_layers=config["num_layers"],dropout=config["dropout"],bidirectional = config['bidirectional'] , batch_first=True)
        # ------------------------- fill in --------------------------------
        self.bidirectional = config['bidirectional']
        self.num_layers = config['num_layers']
        if self.bidirectional:
            self.hidden_size = 2*config['hidden_size']
        else:
            self.hidden_size = config['hidden_size']
        # ------------------------- fill in --------------------------------
        self.outputs = nn.Sequential(
                            nn.Linear(self.hidden_size, self.hidden_size),
                            nn.LeakyReLU(0.2),
                            nn.Linear(self.hidden_size, self.hidden_size),
                            nn.LeakyReLU(0.2),
                            nn.Linear(self.hidden_size, 1),
                            nn.Sigmoid()
                        )
        # ------------------------- fill in --------------------------------
    def forward(self,input, lengths):
        batch_size = input.size(0)
        input_embedding = self.embedding(input) 
        packed_input = rnn_utils.pack_padded_sequence(input_embedding, lengths, batch_first=True)
        _, hidden = self.rnn(packed_input)
        
        if self.bidirectional:
            batch_size = hidden.size()[1]
            hidden = hidden.view(self.num_layers,2,batch_size,-1)
            hidden = hidden.permute(2,0,1,3).contiguous().view(batch_size,self.num_layers,-1)
        else:
            hidden = hidden.permute(1,0,2)
            
        hidden = hidden[:,-1,:]
        outputs = self.outputs(hidden)
        outputs = outputs.squeeze(1)
        return outputs

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 2,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model2 = Sentiment_Classification(config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.681 acc= 0.719
#
#  [200] current_iter_loss= 0.714 acc= 0.562
#
#  [300] current_iter_loss= 0.693 acc= 0.594
#
#  [400] current_iter_loss= 0.532 acc= 0.781
#
#  [500] current_iter_loss= 0.465 acc= 0.844
#
#  [600] current_iter_loss= 0.413 acc= 0.812
#
#  [700] current_iter_loss= 0.497 acc= 0.781
#
#  [800] current_iter_loss= 0.319 acc= 0.844
#
#  [900] current_iter_loss= 0.501 acc= 0.688
#
#  Epoch(1/5) avg train_loss= 0.515 train_acc= 0.727 val_loss= 0.352 val_acc= 0.838
#
#  Epoch(1/5) avg test_loss= 0.382 test_acc= 0.819
# <s> " I see people writing about how great this movie was . It was horrible ! The acting was sub-par at best . It made a lot of money because teenage girls went to see the movie 7 times in the theaters because of Leonardo . Where the hell did they get the money ? Anyway , I wanted to learn more about the Titanic ; why it sank , what was running through a lot of people 's minds ; maybe even a little conspiracy stuff . Does anyone realize that certain people didn 't even board the ship because there was a fire on board before it even took off ? No , you don 't because all you see is a rich girl falling for a poor boy and he paints her naked ( did that corny junk at least tip you off that the movie was stupid ? ) .I did cry in during one scene , though . The scene when they showed the water that was filling up in the ship . It looked like pool water ! I 'm thinking this movie made all this money and they couldn 't even make the water from the ocean look real ? unbelievable ... Ohhh the band played on while the ship sank .. Just ridiculous . This was the worst movie until Pearl Harbor outdid it in the " " Nothing to Do With Reality " " department . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.184 acc= 0.906
#
#  [200] current_iter_loss= 0.239 acc= 0.906
#
#  [300] current_iter_loss= 0.455 acc= 0.688
#
#  [400] current_iter_loss= 0.202 acc= 0.938
#
#  [500] current_iter_loss= 0.230 acc= 0.906
#
#  [600] current_iter_loss= 0.135 acc= 0.969
#
#  [700] current_iter_loss= 0.231 acc= 0.906
#
#  [800] current_iter_loss= 0.247 acc= 0.875
#
#  [900] current_iter_loss= 0.202 acc= 0.906
#
#  Epoch(2/5) avg train_loss= 0.265 train_acc= 0.891 val_loss= 0.267 val_acc= 0.899
#
#  Epoch(2/5) avg test_loss= 0.265 test_acc= 0.883
# <s> " This is a case of a bunch of people thinking they are so clever they have a story that fits the time . Remember the all-around political conspiracies caught on camera in the years leading to the Watergate and a little later ? Most movies trying to cash in on made-for-TV ' o so powerful , o so mind numbing ' conspiracies were in fact caught in their own navel-gazing <unk> was never a fan of The Conversation which I find as much dated as others conspiracy stints of the time but Coppola was true to his main character and Hackman was a pretty engaging actor to observe . I mean these conspiracy movies are mostly drowning in the character pool of noir heroes . Lots of questions unanswered , lots of <unk> ... Well this takes at least Bergman to build a movie about such <unk> <unk> Next Man is a perfect example of its time : one political soup served with an idealistic character and an horrendous conspiracy tightening its web around him . Neither part is interesting in itself and the whole doesn 't get any better . In fact you can tell how much it will be bad from the very first sequences piling up ' <unk> that ' murders without ever advancing any storyline . Pedestrian directing at its worst as most of the movie is one pompous accumulation of scenes revolving around violence naively brought under the viewer 's eyes . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.101 acc= 0.969
#
#  [200] current_iter_loss= 0.248 acc= 0.938
#
#  [300] current_iter_loss= 0.087 acc= 0.969
#
#  [400] current_iter_loss= 0.092 acc= 0.938
#
#  [500] current_iter_loss= 0.095 acc= 0.969
#
#  [600] current_iter_loss= 0.234 acc= 0.938
#
#  [700] current_iter_loss= 0.196 acc= 0.906
#
#  [800] current_iter_loss= 0.119 acc= 0.938
#
#  [900] current_iter_loss= 0.135 acc= 1.000
#
#  Epoch(3/5) avg train_loss= 0.168 train_acc= 0.936 val_loss= 0.303 val_acc= 0.884
#
#  Epoch(3/5) avg test_loss= 0.279 test_acc= 0.896
# <s> " This is an installment in the notorious Guinea Pig series . A short lived japanese TV-show , that got cancelled after a psychopath admitted to being inspired in the killing of a young schoolgirl by the show . This short in the series is , like all the other films in the series , practically without any story . A group of guys have captured a young woman . They tie her down and proceeds to torturing her to death while <unk> her . They beat her , pour boiling oil over her , use pliers on her and finally , in " " loving " " closeup , push a needle through her eye . This is the most straightforward of all the Guinea Pig movies , and one of the first . It was probably this film , more than any of the others , that gave Guinea Pig the rumour of being snuff . They certainly gave inspiration to Nicolas Cage 's movie " " 8 mm . " . " These movies have gotten quite popular in horror circles . They have progressed to more polished , but equally graphic movies like " " Naked Blood " . " They probably fill the void left by the Mondo movies , that got slightly cleaned up and became reality TV . Not recommended , but will probably allure those who will see anything once , and wonder why afterwards , I know I did . , " </s>
#
#  Pred: positive, Ans: negative
#
#  [100] current_iter_loss= 0.021 acc= 1.000
#
#  [200] current_iter_loss= 0.023 acc= 1.000
#
#  [300] current_iter_loss= 0.086 acc= 0.969
#
#  [400] current_iter_loss= 0.037 acc= 1.000
#
#  [500] current_iter_loss= 0.004 acc= 1.000
#
#  [600] current_iter_loss= 0.042 acc= 1.000
#
#  [700] current_iter_loss= 0.135 acc= 0.906
#
#  [800] current_iter_loss= 0.261 acc= 0.906
#
#  [900] current_iter_loss= 0.238 acc= 0.938
#
#  Epoch(4/5) avg train_loss= 0.100 train_acc= 0.965 val_loss= 0.293 val_acc= 0.880
#
#  Epoch(4/5) avg test_loss= 0.312 test_acc= 0.889
# <s> " I see people writing about how great this movie was . It was horrible ! The acting was sub-par at best . It made a lot of money because teenage girls went to see the movie 7 times in the theaters because of Leonardo . Where the hell did they get the money ? Anyway , I wanted to learn more about the Titanic ; why it sank , what was running through a lot of people 's minds ; maybe even a little conspiracy stuff . Does anyone realize that certain people didn 't even board the ship because there was a fire on board before it even took off ? No , you don 't because all you see is a rich girl falling for a poor boy and he paints her naked ( did that corny junk at least tip you off that the movie was stupid ? ) .I did cry in during one scene , though . The scene when they showed the water that was filling up in the ship . It looked like pool water ! I 'm thinking this movie made all this money and they couldn 't even make the water from the ocean look real ? unbelievable ... Ohhh the band played on while the ship sank .. Just ridiculous . This was the worst movie until Pearl Harbor outdid it in the " " Nothing to Do With Reality " " department . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.009 acc= 1.000
#
#  [200] current_iter_loss= 0.003 acc= 1.000
#
#  [300] current_iter_loss= 0.084 acc= 0.938
#
#  [400] current_iter_loss= 0.004 acc= 1.000
#
#  [500] current_iter_loss= 0.020 acc= 1.000
#
#  [600] current_iter_loss= 0.006 acc= 1.000
#
#  [700] current_iter_loss= 0.019 acc= 1.000
#
#  [800] current_iter_loss= 0.142 acc= 0.969
#
#  [900] current_iter_loss= 0.042 acc= 0.969
#
#  Epoch(5/5) avg train_loss= 0.054 train_acc= 0.984 val_loss= 0.405 val_acc= 0.887
#
#  Epoch(5/5) avg test_loss= 0.389 test_acc= 0.889
# <s> " Before the release of George Romero 's genre-defining Night of the Living Dead , zombies were relatively <unk> creatures . They certainly had much better <unk> in the old days . But social etiquette aside what thrills did these early zombies offer to the movie-going public ? Judging by this film , none whatsoever.The story is about an expedition to Cambodia , whose purpose is to find and destroy the secret of <unk> . One of the party discovers the secrets on his own and sets about building his zombie army.This film is basically a love triangle with zombies . But seeing as this is a 30 's movie , the said zombies are more like <unk> than the flesh-eating variety we think of today . They seem to respond to mind-control , rather than insatiable appetites . And , quite frankly , the ' revolt ' is somewhat underwhelming too . The whole thing is really very dull . Aside from the lack of horror , there isn 't any over-the-top melodramatic theatrics to keep us entertained . It seems unlikely that this could 've provided much entertainment even 70 years ago . See it if you have to see everything with ' zombie ' in the title but otherwise I would advise skipping this one . , " </s>
#
#  Pred: negative, Ans: negative

# %% [markdown]
# ## Let's Do it

# %%
config = {
  "epochs": 5,
  "hidden_size": 64,
  "bidirectional": True,
  "num_layers": 2,
  "dropout": 0.2,
  "batch_size": 32,
  "embedding_size": 64,
  "learning_rate": 0.001,
}

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model2 = Sentiment_Classification(config, config, vocab_size=len(vocab))
model2 = model2.to(device)
optimizer = torch.optim.Adam(model2.parameters(), lr=config.get("learning_rate", .001))

# Train model
for epoch in range(config["epochs"]):
    model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
    evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
# Out:
#  [100] current_iter_loss= 0.695 acc= 0.500
#
#  [200] current_iter_loss= 0.718 acc= 0.469
#
#  [300] current_iter_loss= 0.559 acc= 0.688
#
#  [400] current_iter_loss= 0.618 acc= 0.656
#
#  [500] current_iter_loss= 0.562 acc= 0.688
#
#  [600] current_iter_loss= 0.651 acc= 0.750
#
#  [700] current_iter_loss= 0.404 acc= 0.781
#
#  [800] current_iter_loss= 0.291 acc= 0.906
#
#  [900] current_iter_loss= 0.330 acc= 0.812
#
#  Epoch(1/5) avg train_loss= 0.500 train_acc= 0.735 val_loss= 0.331 val_acc= 0.850
#
#  Epoch(1/5) avg test_loss= 0.316 test_acc= 0.867
# <s> " I have always loved old movies but this is one of my top ten favorites ... it has all the charm , 1940 's <unk> , and good old fashioned romance and it 's hilarious , to boot ! Barbara Stanwick plays an independent single woman who writes cooking \ home life articles for a famous magazine ... under the premise that she is a married homemaker . Even the president of the magazine is under this delusion . Enter a handsome GI , ( played by the talented Dennis Morgan ) just rescued off of a raft along with his buddy . His simple wish is to stay at the <unk> <unk> the she writes so eloquently about and relax with her famous <unk> meals . She now has to frantically find a way to save her job and reputation ... add to this that her fianc챕 is in a hurry to tie the knot doesn 't help . The humor is superb and the chemistry between the leading characters a lot of fun . Throw in the <unk> nicknamed " " Cuddles " " ( who fits this name completely ) it becomes even more adorable . This has become my must-see movie that I <unk> in with a cup of <unk> each Christmas season . A wonderful , enjoyable movie to enjoy at <unk> or anytime ! , " </s>
#
#  Pred: positive, Ans: positive
#
#  [100] current_iter_loss= 0.253 acc= 0.875
#
#  [200] current_iter_loss= 0.390 acc= 0.875
#
#  [300] current_iter_loss= 0.235 acc= 0.938
#
#  [400] current_iter_loss= 0.237 acc= 0.969
#
#  [500] current_iter_loss= 0.268 acc= 0.875
#
#  [600] current_iter_loss= 0.253 acc= 0.938
#
#  [700] current_iter_loss= 0.173 acc= 0.938
#
#  [800] current_iter_loss= 0.254 acc= 0.906
#
#  [900] current_iter_loss= 0.268 acc= 0.906
#
#  Epoch(2/5) avg train_loss= 0.254 train_acc= 0.895 val_loss= 0.265 val_acc= 0.888
#
#  Epoch(2/5) avg test_loss= 0.283 test_acc= 0.873
# <s> " I hated this show when I was a kid . That was back in the day when kids show characters actually had accents , not just the bland , generic , General American <unk> we 're used to . Jack Wild had a British accent and Pufnstuf 's was southern . Like one of the others mentioned , though , I never quite understood what the deal was with the witch wanting the flute . That always seemed odd to me , probably because the flute just annoyed me and I wouldn 't have gone to any trouble to take it away ! Just a comment on the similarity of Pufnstuf to early 70s McDonalds commercials that others have mentioned : Pufnstuf ripped off McDonalds . At the height of McDonalds popularity , the TV show ( or rather , their creators ) sought to license McDonalds characters for their show , but when McDonalds declined the TV show changed the characters slightly and passed it as their own . They even hired former employees of McDonalds ad agency and the voice actors to make the TV shows . McDonalds sued and won . Search for Pufnstuf <unk> lawsuit and you 'll find plenty of articles about it . , " </s>
#
#  Pred: negative, Ans: negative
#
#  [100] current_iter_loss= 0.258 acc= 0.906
#
#  [200] current_iter_loss= 0.077 acc= 0.969
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-504e87e99f23> in <module>()
#       8 # Train model
#       9 for epoch in range(config["epochs"]):
# ---> 10     model,optimizer  = sentiment_trainer(model2,optimizer, loaders, epoch,config["epochs"])
#      11     evaluate(model, test_data_loader, epoch,config["epochs"], id2word)
#
# <ipython-input-118-238c2acf84e9> in sentiment_trainer(model, optimizer, loaders, epoch, n_epochs)
#      15     for split in loaders.keys():
#      16         if split == "train":
# ---> 17             for batch in loaders[split]:
#      18         # ------------------------- fill in --------------------------------
#      19                 model.train() # train mode
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# <ipython-input-85-747c67f9b981> in __getitem__(self, index)
#       8         """Returns one data pair (source and sentiment)."""
#       9         seqs = self.seqs[index]
# ---> 10         seqs, label = self.process(seqs, self.word2id)
#      11         return seqs, label
#      12
#
# <ipython-input-85-747c67f9b981> in process(self, seq, word2id)
#      21         for i in range(0, len(words)-1):
#      22             current_word = words[i]
# ---> 23             if "negative" == words[len(words)-1]: #if label is "neg", then 1
#      24                 label = 1
#      25             if current_word in word2id:
#
# KeyboardInterrupt:
